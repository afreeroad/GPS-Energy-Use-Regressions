# %%
### GPS Data Set
### The GOAL here is to transform the GPS individual.csv data set into a new dataframe consisting of ---
### the country names as columns, and the rows consisting of the preference data we assign.

import pandas as pd
import numpy as np

## import the data
ind_data = pd.read_csv('individual.csv')

## transform ind_data into a data frame and sort the country column alphabetically, retaining assoc. data
df_ind_data = pd.DataFrame(ind_data)
new_data = df_ind_data.sort_values(by=['country'])

## reset new_data index to 0,1,2,3...etc
new_data = new_data.reset_index(drop=True)

## create a list of the country names, alphabetically
country_list = list(ind_data['country'])
new_country_set = sorted(set(country_list))

## form a dictionary to append our data into
d = dict.fromkeys(new_country_set, [])

## since the country column of ind_data includes all 76 countries within 80000 rows, we must separate which sets of ---
## rows apply to which country, making sure the exact data for that country is chosen and transformed into the ---
## data set.
lengths = []
for country in new_country_set:
    pink = new_data.loc[(new_data['country'] == country)] #locate all rows for 'Afghanistan' (and so on)
    value = list(pink.trust) #create a list of the 'trust' data for 'Afghanistan' -- this is hard-coded...fix this
    lengths.append(len(value)) # the rows of data for each country differ, and we need to know the difference later.
max_length = max(lengths)

for country in new_country_set:
    pink = new_data.loc[(new_data['country'] == country)]
    value = list(pink.trust)
    while len(value) < max_length:  #python won't let us have columns of differing lengths, so we add in "NaN" values---
        value.append(np.NaN)        #for columns with # of rows less than the maximum.
    d[country] = value

## Create the new DataFrame and print to CSV.
data_frame = pd.DataFrame(d)
#data_frame.to_csv('dataframe_copy.csv')
print(data_frame)



### ISSUES: this code is hard-coded for the 'trust' category of data. We need to create something which loops ---
### through all data categories and prints a csv with named csv i.e "dataframe_trust", dataframe_patience" et al.
# Out:
#       Afghanistan   Algeria  Argentina  Australia   Austria  Bangladesh  \
# 0        0.950434 -0.508207   0.950434   0.585774 -1.966847   -0.872867
# 1        0.950434  0.585774  -0.143547   1.315094  0.585774   -0.508207
# 2        0.585774 -0.508207  -1.237527   0.585774  0.950434   -0.872867
# 3        0.950434 -0.143547  -0.143547   1.679754 -1.237527   -0.508207
# 4       -0.143547  0.585774   0.221113   0.221113 -1.966847   -0.143547
# 5        0.221113 -1.237527  -0.872867   0.585774  0.950434    1.679754
# 6       -0.508207  0.585774   0.221113   0.221113 -1.237527    0.585774
# 7       -0.508207  0.221113  -1.602187   0.221113 -1.237527    0.585774
# 8       -1.237527 -0.143547   0.585774   0.585774  1.679754    0.585774
# 9       -1.237527  0.950434   1.315094  -1.966847  0.950434   -0.872867
# 10      -0.872867  1.315094  -0.143547  -0.143547  0.221113   -0.143547
# 11      -0.872867 -1.602187   0.221113  -1.237527  0.221113   -0.508207
# 12       0.221113  1.315094  -1.966847   1.679754 -0.872867   -1.237527
# 13      -0.872867  0.585774   0.585774  -0.508207 -0.872867   -0.872867
# 14       0.585774 -1.237527   0.221113  -0.143547  0.950434   -0.143547
# 15      -1.966847  0.950434  -0.143547   0.585774 -0.143547   -0.143547
# 16            NaN  0.221113   1.679754  -0.143547  1.679754   -0.508207
# 17      -1.966847  0.950434  -0.143547   1.315094 -0.872867   -0.143547
# 18      -1.966847 -0.143547  -0.143547  -1.966847  0.221113    0.221113
# 19       1.679754  0.950434  -0.508207  -0.143547  0.950434   -0.872867
# 20      -0.143547 -0.508207  -0.872867   0.950434  1.679754   -0.143547
# 21      -0.872867 -1.602187  -1.237527   0.585774  0.950434   -0.143547
# 22       1.315094 -1.237527   0.585774  -0.508207 -0.143547   -0.143547
# 23       0.950434 -1.602187  -0.143547   0.950434  1.315094   -0.508207
# 24      -0.143547 -1.602187   0.950434   1.679754  1.679754   -0.508207
# 25      -1.966847 -1.602187  -1.602187   1.315094 -1.966847   -0.143547
# 26       1.679754 -1.237527  -0.143547   1.315094 -0.508207   -0.143547
# 27            NaN -0.872867   0.950434   0.950434 -0.872867   -0.143547
# 28      -0.508207  1.315094  -1.602187  -0.508207  1.679754   -0.143547
# 29      -1.966847 -1.237527   0.585774   0.585774 -0.508207   -0.872867
# ...           ...       ...        ...        ...       ...         ...
# 2544          NaN       NaN        NaN        NaN       NaN         NaN
# 2545          NaN       NaN        NaN        NaN       NaN         NaN
# 2546          NaN       NaN        NaN        NaN       NaN         NaN
# 2547          NaN       NaN        NaN        NaN       NaN         NaN
# 2548          NaN       NaN        NaN        NaN       NaN         NaN
# 2549          NaN       NaN        NaN        NaN       NaN         NaN
# 2550          NaN       NaN        NaN        NaN       NaN         NaN
# 2551          NaN       NaN        NaN        NaN       NaN         NaN
# 2552          NaN       NaN        NaN        NaN       NaN         NaN
# 2553          NaN       NaN        NaN        NaN       NaN         NaN
# 2554          NaN       NaN        NaN        NaN       NaN         NaN
# 2555          NaN       NaN        NaN        NaN       NaN         NaN
# 2556          NaN       NaN        NaN        NaN       NaN         NaN
# 2557          NaN       NaN        NaN        NaN       NaN         NaN
# 2558          NaN       NaN        NaN        NaN       NaN         NaN
# 2559          NaN       NaN        NaN        NaN       NaN         NaN
# 2560          NaN       NaN        NaN        NaN       NaN         NaN
# 2561          NaN       NaN        NaN        NaN       NaN         NaN
# 2562          NaN       NaN        NaN        NaN       NaN         NaN
# 2563          NaN       NaN        NaN        NaN       NaN         NaN
# 2564          NaN       NaN        NaN        NaN       NaN         NaN
# 2565          NaN       NaN        NaN        NaN       NaN         NaN
# 2566          NaN       NaN        NaN        NaN       NaN         NaN
# 2567          NaN       NaN        NaN        NaN       NaN         NaN
# 2568          NaN       NaN        NaN        NaN       NaN         NaN
# 2569          NaN       NaN        NaN        NaN       NaN         NaN
# 2570          NaN       NaN        NaN        NaN       NaN         NaN
# 2571          NaN       NaN        NaN        NaN       NaN         NaN
# 2572          NaN       NaN        NaN        NaN       NaN         NaN
# 2573          NaN       NaN        NaN        NaN       NaN         NaN
#
#        Bolivia  Bosnia Herzegovina  Botswana    Brazil    ...     Thailand  \
# 0     0.950434            0.585774 -0.508207  0.585774    ...     0.950434
# 1     1.679754           -0.143547 -0.872867  0.221113    ...     1.315094
# 2     1.679754            0.950434  0.221113 -0.143547    ...     1.315094
# 3    -0.143547            0.221113 -1.602187  0.585774    ...     0.950434
# 4     1.679754            0.221113  0.950434 -0.508207    ...     0.950434
# 5    -1.237527            1.315094  0.221113  0.221113    ...    -0.508207
# 6    -0.143547            0.221113 -0.508207  0.585774    ...     0.585774
# 7    -0.508207            1.679754 -0.872867  0.221113    ...     0.950434
# 8    -0.143547            1.679754 -0.872867  0.221113    ...     0.221113
# 9    -0.143547            0.221113  0.221113 -0.143547    ...     0.585774
# 10   -0.143547           -0.872867 -1.602187  1.315094    ...     0.950434
# 11    0.221113            0.585774 -1.602187 -0.143547    ...     0.585774
# 12    1.679754            1.679754 -1.966847  0.221113    ...     0.585774
# 13   -0.143547            1.315094 -1.602187  1.315094    ...     0.950434
# 14    0.585774            1.679754 -0.143547  0.950434    ...     0.585774
# 15   -0.143547           -1.237527 -1.602187 -0.872867    ...     1.315094
# 16    0.221113            0.221113 -0.872867  0.221113    ...     1.315094
# 17    1.315094           -0.143547  0.950434 -0.872867    ...     0.950434
# 18   -0.143547           -0.143547 -0.143547  0.585774    ...     0.950434
# 19   -1.966847           -0.143547 -0.872867 -0.143547    ...     0.950434
# 20    1.679754            0.585774 -1.237527 -1.237527    ...    -1.237527
# 21   -0.143547           -0.508207 -1.966847  0.950434    ...     0.950434
# 22         NaN                 NaN  0.950434  0.221113    ...     0.585774
# 23   -1.237527            0.221113 -0.143547  0.585774    ...    -0.872867
# 24   -1.966847            0.221113 -0.143547 -1.966847    ...    -0.143547
# 25    0.950434            1.679754 -1.237527 -0.143547    ...    -0.872867
# 26   -0.143547            0.585774  0.585774 -0.872867    ...    -0.508207
# 27   -0.143547            0.585774 -0.872867  0.221113    ...     0.221113
# 28         NaN           -0.508207 -0.508207  0.585774    ...     0.221113
# 29    1.315094           -1.237527 -0.872867 -1.602187    ...    -0.143547
# ...        ...                 ...       ...       ...    ...          ...
# 2544       NaN                 NaN       NaN       NaN    ...          NaN
# 2545       NaN                 NaN       NaN       NaN    ...          NaN
# 2546       NaN                 NaN       NaN       NaN    ...          NaN
# 2547       NaN                 NaN       NaN       NaN    ...          NaN
# 2548       NaN                 NaN       NaN       NaN    ...          NaN
# 2549       NaN                 NaN       NaN       NaN    ...          NaN
# 2550       NaN                 NaN       NaN       NaN    ...          NaN
# 2551       NaN                 NaN       NaN       NaN    ...          NaN
# 2552       NaN                 NaN       NaN       NaN    ...          NaN
# 2553       NaN                 NaN       NaN       NaN    ...          NaN
# 2554       NaN                 NaN       NaN       NaN    ...          NaN
# 2555       NaN                 NaN       NaN       NaN    ...          NaN
# 2556       NaN                 NaN       NaN       NaN    ...          NaN
# 2557       NaN                 NaN       NaN       NaN    ...          NaN
# 2558       NaN                 NaN       NaN       NaN    ...          NaN
# 2559       NaN                 NaN       NaN       NaN    ...          NaN
# 2560       NaN                 NaN       NaN       NaN    ...          NaN
# 2561       NaN                 NaN       NaN       NaN    ...          NaN
# 2562       NaN                 NaN       NaN       NaN    ...          NaN
# 2563       NaN                 NaN       NaN       NaN    ...          NaN
# 2564       NaN                 NaN       NaN       NaN    ...          NaN
# 2565       NaN                 NaN       NaN       NaN    ...          NaN
# 2566       NaN                 NaN       NaN       NaN    ...          NaN
# 2567       NaN                 NaN       NaN       NaN    ...          NaN
# 2568       NaN                 NaN       NaN       NaN    ...          NaN
# 2569       NaN                 NaN       NaN       NaN    ...          NaN
# 2570       NaN                 NaN       NaN       NaN    ...          NaN
# 2571       NaN                 NaN       NaN       NaN    ...          NaN
# 2572       NaN                 NaN       NaN       NaN    ...          NaN
# 2573       NaN                 NaN       NaN       NaN    ...          NaN
#
#         Turkey    Uganda   Ukraine  United Arab Emirates  United Kingdom  \
# 0     0.950434 -1.237527 -0.143547              0.950434        1.315094
# 1     0.585774 -1.966847  1.315094             -1.966847       -1.602187
# 2     0.585774 -1.966847  1.315094              1.679754       -0.508207
# 3    -0.143547 -1.966847 -0.872867              1.679754       -0.508207
# 4     1.315094 -1.966847 -0.508207              1.679754        1.679754
# 5    -1.966847 -1.966847 -1.237527              1.679754        0.585774
# 6     0.950434 -1.966847  0.221113             -1.602187        0.950434
# 7    -0.143547 -1.966847 -0.143547              1.679754        0.950434
# 8    -0.143547 -0.872867 -0.872867              1.679754        0.585774
# 9    -0.872867 -0.143547 -0.872867              1.679754       -0.872867
# 10    0.221113 -0.143547 -1.237527              1.679754       -0.143547
# 11    1.679754  0.950434  0.950434              1.679754        0.221113
# 12   -0.143547 -1.602187  0.950434             -1.602187        0.585774
# 13   -0.143547 -1.602187 -0.143547              1.679754       -0.143547
# 14    0.585774 -1.602187 -0.143547              1.679754        0.585774
# 15    1.315094  0.585774 -1.237527              1.679754       -0.143547
# 16    1.315094  0.950434  0.585774             -0.508207        0.585774
# 17    0.221113 -1.602187  0.585774             -1.602187        1.679754
# 18   -0.872867 -0.143547 -1.237527              0.950434       -0.508207
# 19   -0.872867 -1.602187 -0.872867              1.315094       -0.143547
# 20   -0.872867 -1.237527  0.221113              1.315094        1.679754
# 21   -0.143547 -0.872867 -0.872867              1.315094        0.950434
# 22    0.585774 -1.237527  0.950434              0.950434        0.221113
# 23    0.221113 -1.237527 -1.602187              0.950434        0.221113
# 24   -0.143547 -1.966847 -0.143547              1.315094        0.950434
# 25    0.950434 -0.143547 -0.872867              0.221113       -0.508207
# 26   -0.143547 -0.872867 -0.143547             -0.143547        0.221113
# 27   -0.143547  0.950434 -0.143547              1.315094        1.679754
# 28    0.585774 -1.966847       NaN              0.585774       -0.143547
# 29   -0.143547 -0.143547       NaN             -1.966847       -1.237527
# ...        ...       ...       ...                   ...             ...
# 2544       NaN       NaN       NaN                   NaN             NaN
# 2545       NaN       NaN       NaN                   NaN             NaN
# 2546       NaN       NaN       NaN                   NaN             NaN
# 2547       NaN       NaN       NaN                   NaN             NaN
# 2548       NaN       NaN       NaN                   NaN             NaN
# 2549       NaN       NaN       NaN                   NaN             NaN
# 2550       NaN       NaN       NaN                   NaN             NaN
# 2551       NaN       NaN       NaN                   NaN             NaN
# 2552       NaN       NaN       NaN                   NaN             NaN
# 2553       NaN       NaN       NaN                   NaN             NaN
# 2554       NaN       NaN       NaN                   NaN             NaN
# 2555       NaN       NaN       NaN                   NaN             NaN
# 2556       NaN       NaN       NaN                   NaN             NaN
# 2557       NaN       NaN       NaN                   NaN             NaN
# 2558       NaN       NaN       NaN                   NaN             NaN
# 2559       NaN       NaN       NaN                   NaN             NaN
# 2560       NaN       NaN       NaN                   NaN             NaN
# 2561       NaN       NaN       NaN                   NaN             NaN
# 2562       NaN       NaN       NaN                   NaN             NaN
# 2563       NaN       NaN       NaN                   NaN             NaN
# 2564       NaN       NaN       NaN                   NaN             NaN
# 2565       NaN       NaN       NaN                   NaN             NaN
# 2566       NaN       NaN       NaN                   NaN             NaN
# 2567       NaN       NaN       NaN                   NaN             NaN
# 2568       NaN       NaN       NaN                   NaN             NaN
# 2569       NaN       NaN       NaN                   NaN             NaN
# 2570       NaN       NaN       NaN                   NaN             NaN
# 2571       NaN       NaN       NaN                   NaN             NaN
# 2572       NaN       NaN       NaN                   NaN             NaN
# 2573       NaN       NaN       NaN                   NaN             NaN
#
#       United States  Venezuela   Vietnam  Zimbabwe
# 0          0.950434   1.679754 -0.143547  1.679754
# 1         -0.508207  -1.237527  0.950434 -0.143547
# 2          0.950434  -0.143547  0.950434 -0.508207
# 3          0.221113  -0.508207  0.585774 -0.143547
# 4         -0.143547  -0.143547       NaN  0.950434
# 5         -0.143547  -0.143547  0.585774 -0.143547
# 6         -0.872867  -0.508207       NaN -0.143547
# 7          0.221113   0.221113  0.585774  0.221113
# 8         -1.966847   0.585774  0.585774 -0.143547
# 9          0.950434   0.221113       NaN -0.508207
# 10        -1.237527   0.221113       NaN -0.143547
# 11         0.950434  -0.508207       NaN  0.221113
# 12         0.221113   0.221113       NaN -1.602187
# 13         0.585774   0.221113       NaN -0.872867
# 14        -0.143547  -0.143547       NaN  0.221113
# 15        -0.143547   0.585774       NaN  0.221113
# 16         0.950434   1.679754       NaN  0.221113
# 17        -0.508207   0.221113       NaN -0.872867
# 18         0.585774   0.950434 -0.508207 -0.872867
# 19         0.950434   1.315094  0.585774  1.315094
# 20         1.679754   0.585774  0.950434 -0.143547
# 21        -0.143547  -0.143547       NaN -0.143547
# 22              NaN  -1.966847  0.950434  0.585774
# 23         1.679754  -0.508207  0.950434 -1.237527
# 24         0.585774  -0.508207  0.950434 -0.508207
# 25        -0.143547  -0.508207       NaN -0.508207
# 26         1.679754   1.679754  1.315094 -0.508207
# 27         0.950434   1.679754  0.585774  1.315094
# 28         1.315094   0.221113  1.315094 -0.143547
# 29         1.679754  -0.508207  0.585774 -1.966847
# ...             ...        ...       ...       ...
# 2544            NaN        NaN       NaN       NaN
# 2545            NaN        NaN       NaN       NaN
# 2546            NaN        NaN       NaN       NaN
# 2547            NaN        NaN       NaN       NaN
# 2548            NaN        NaN       NaN       NaN
# 2549            NaN        NaN       NaN       NaN
# 2550            NaN        NaN       NaN       NaN
# 2551            NaN        NaN       NaN       NaN
# 2552            NaN        NaN       NaN       NaN
# 2553            NaN        NaN       NaN       NaN
# 2554            NaN        NaN       NaN       NaN
# 2555            NaN        NaN       NaN       NaN
# 2556            NaN        NaN       NaN       NaN
# 2557            NaN        NaN       NaN       NaN
# 2558            NaN        NaN       NaN       NaN
# 2559            NaN        NaN       NaN       NaN
# 2560            NaN        NaN       NaN       NaN
# 2561            NaN        NaN       NaN       NaN
# 2562            NaN        NaN       NaN       NaN
# 2563            NaN        NaN       NaN       NaN
# 2564            NaN        NaN       NaN       NaN
# 2565            NaN        NaN       NaN       NaN
# 2566            NaN        NaN       NaN       NaN
# 2567            NaN        NaN       NaN       NaN
# 2568            NaN        NaN       NaN       NaN
# 2569            NaN        NaN       NaN       NaN
# 2570            NaN        NaN       NaN       NaN
# 2571            NaN        NaN       NaN       NaN
# 2572            NaN        NaN       NaN       NaN
# 2573            NaN        NaN       NaN       NaN
#
# [2574 rows x 76 columns]

# %%
mean_afg = np.mean(data_frame['Afghanistan'])
print(mean_afg)
# Out:
# 0.31755251420454544

# %%
# # holy shit, 'unstack' is dope. Need to try this on the ipynb. Does all the work of converting the dataframe.
# #dfu = df.unstack(level=0)
# #print(dfu)
